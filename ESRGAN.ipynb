# %% [markdown]
# <a href="https://colab.research.google.com/github/BDfriends/ESRGAN/blob/master/ESRGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/xinntao/ESRGAN
# %cd ESRGAN
# Out:
# Cloning into 'ESRGAN'...
# remote: Enumerating objects: 225, done.
# remote: Total 225 (delta 0), reused 0 (delta 0), pack-reused 225
# Receiving objects: 100% (225/225), 24.86 MiB | 39.10 MiB/s, done.
# Resolving deltas: 100% (86/86), done.
# /content/ESRGAN

# %%
# %cd models
# Out:
# /content/ESRGAN/models

# %%
# !gdown 1TPrz5QKd8DHHt1k8SRtm6tMiPjz_Qene
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1TPrz5QKd8DHHt1k8SRtm6tMiPjz_Qene
# To: /content/ESRGAN/models/RRDB_ESRGAN_x4.pth
# 100% 66.9M/66.9M [00:00<00:00, 230MB/s]

# %%
# %cd ..
# Out:
# /content/ESRGAN

# %%
# !python test.py
# Out:
# Model path models/RRDB_ESRGAN_x4.pth.
# Testing...
# 1 comic
# 2 baboon

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib import rcParams

# %matplotlib inline

# figure size in inches optional
rcParams['figure.figsize'] = 11 ,8

# read images
img_A = mpimg.imread('/content/ESRGAN/LR/baboon.png')
img_B = mpimg.imread('/content/ESRGAN/results/baboon_rlt.png')

# display images
fig, ax = plt.subplots(1,2)
ax[0].imshow(img_A)
ax[1].imshow(img_B)
